# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/website_classification.csv")
df.head()
# Out:
#    Unnamed: 0                                        website_url  \
# 0           0     https://www.booking.com/index.html?aid=1743217
# 1           1                   https://travelsites.com/expedia/
# 2           2               https://travelsites.com/tripadvisor/
# 3           3              https://www.momondo.in/?ispredir=true
# 4           4  https://www.ebookers.com/?AFFCID=EBOOKERS-UK.n...
#
#                                 cleaned_website_text Category
# 0  official site good hotel accommodation big sav...   Travel
# 1  expedia hotel book sites like use vacation wor...   Travel
# 2  tripadvisor hotel book sites like previously d...   Travel
# 3  cheap flights search compare flights momondo f...   Travel
# 4  bot create free account create free account si...   Travel

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1408 entries, 0 to 1407
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            1408 non-null   int64
#  1   website_url           1408 non-null   object
#  2   cleaned_website_text  1408 non-null   object
#  3   Category              1408 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 44.1+ KB

# %%
df['Category'].unique()
# Out:
# array(['Travel', 'Social Networking and Messaging', 'News',
#        'Streaming Services', 'Sports', 'Photography',
#        'Law and Government', 'Health and Fitness', 'Games', 'E-Commerce',
#        'Forums', 'Food', 'Education', 'Computers and Technology',
#        'Business/Corporate', 'Adult'], dtype=object)

# %%
df.isna().sum()
# Out:
# Unnamed: 0              0
# website_url             0
# cleaned_website_text    0
# Category                0
# dtype: int64

# %%
df.groupby("Category").count().sort_values(by = "Category" , ascending = True)
# Out:
#                                  Unnamed: 0  website_url  cleaned_website_text
# Category
# Adult                                    16           16                    16
# Business/Corporate                      109          109                   109
# Computers and Technology                 93           93                    93
# E-Commerce                              102          102                   102
# Education                               114          114                   114
# Food                                     92           92                    92
# Forums                                   16           16                    16
# Games                                    98           98                    98
# Health and Fitness                       96           96                    96
# Law and Government                       84           84                    84
# News                                     96           96                    96
# ...

# %%
keywords = " ".join(df["cleaned_website_text"].tolist())
wordcloud = WordCloud(contour_color='black' , max_words=200 , width=800 , height=400).generate(keywords).to_image()
wordcloud
# Out:
# <PIL.Image.Image image mode=RGB size=800x400>
